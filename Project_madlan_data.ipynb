# %%
import pandas as pd
import numpy as np
import re
import matplotlib.pyplot as plt 
import pickle

# %% [markdown]
# ### Loading a CSV file into DATAFRAME

# %%
data1 = pd.read_excel('C:/Users/Admin/Downloads/output_all_students_Train_v10.xlsx')
data = data1.copy()

# %% [markdown]
# ### Deletion of properties where there is no price

# %%
data_filter = data.dropna(subset=["price"])
data_filter.head()
# Out:
#         City  type room_number Area         Street number_in_street  \
# 0  פתח תקווה  דירה         5.5  137     רפאלי שרגא                3
# 1  פתח תקווה  דירה           3   84  כצנלסון אהרון                6
# 2  פתח תקווה  דירה           4  120       הירקונים               17
# 3  פתח תקווה  דירה         3.5  110     סלנט שמואל               56
# 4  פתח תקווה  דירה         4.5  120    בן צבי יצחק               28
#
#           city_area    price  num_of_images     floor_out_of  ... hasStorage   \
# 0  אם המושבות החדשה  3600000            6.0  קומה 11 מתוך 19  ...       False
# 1           נווה גן  2550000            6.0    קומה 6 מתוך 9  ...        True
# 2   קרית הרב סלומון  2650000           10.0    קומה 2 מתוך 7  ...        True
# 3        המרכז השקט  2450000            8.0    קומה 2 מתוך 6  ...       False
# 4        כפר גנים ב  2720000            9.0    קומה 3 מתוך 6  ...       False
#
#   condition  hasAirCondition  hasBalcony  hasMamad  handicapFriendly   \
# 0       שמור             True       False      True              True
# 1       שמור             True       False      True             False
# 2        חדש             True        True      True             False
# 3      משופץ             True       False      True              True
# 4      משופץ             True        True      True              True
#
#   entranceDate  furniture  publishedDays   \
# 0          גמיש   לא צויין              7
# 1         מיידי   לא צויין              8
# 2          גמיש       חלקי              6
# 3          גמיש       חלקי              8
# 4          גמיש   לא צויין             21
#
#                                         description
# 0  למכירה 5.5 חדרים ענקית, מרווחת , מוארת , קומה ...
# 1  למכירה מפרטי ברחוב אהרון כצנלסון השקט והמבוקש,...
# 2  פריים לוקשיין בשכונת שיפר המאוד מבוקשת!!! למכי...
# 3  בפתח תקווה ברחוב שמואל סלנט המבוקש,לא כדאי לפס...
# 4  הדירה משופצת חלקית בטעם טוב , פונה לעורף לכיוו...
#
# [5 rows x 23 columns]

# %%
data_filter['City'] = data_filter['City'].str.replace('נהרייה', 'נהריה')
data_filter['City'] = data_filter['City'].str.replace(' שוהם', 'שוהם')
for col in ['City', 'type','Street' ,'condition ']:
    if data_filter[col].dtype == 'object':
        data_filter[col] = data_filter[col].str.strip()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_12836\813113222.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_filter['City'] = data_filter['City'].str.replace('נהרייה', 'נהריה')
# C:\Users\Admin\AppData\Local\Temp\ipykernel_12836\813113222.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_filter['City'] = data_filter['City'].str.replace(' שוהם', 'שוהם')
# C:\Users\Admin\AppData\Local\Temp\ipykernel_12836\813113222.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_filter[col] = data_filter[col].str.strip()

# %% [markdown]
# ### Checking that values are of numeric type and converting to a numeric value

# %%
def extract_number(price):
    if isinstance(price, str):
        # Remove any non-digit characters using regular expressions
        numeric_part = re.sub(r'[^0-9]', '', price)
        try:
            # Convert the remaining string to an integer
            number = int(numeric_part)
            return number
        except ValueError:
            return np.nan
    else:
        return price

data_filter.loc[:, 'price'] = data_filter['price'].apply(extract_number)
data_filter.loc[:, 'Area'] = data_filter['Area'].apply(extract_number)

data_filter
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_12836\423740098.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_filter.loc[:, 'price'] = data_filter['price'].apply(extract_number)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_12836\423740098.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_filter.loc[:, 'Area'] = data_filter['Area'].apply(extract_number)
#           City      type room_number   Area         Street number_in_street  \
# 0    פתח תקווה      דירה         5.5  137.0     רפאלי שרגא                3
# 1    פתח תקווה      דירה           3   84.0  כצנלסון אהרון                6
# 2    פתח תקווה      דירה           4  120.0       הירקונים               17
# 3    פתח תקווה      דירה         3.5  110.0     סלנט שמואל               56
# 4    פתח תקווה      דירה         4.5  120.0    בן צבי יצחק               28
# ..         ...       ...         ...    ...            ...              ...
# 694      רעננה  בית פרטי     9.5 חד׳  350.0           הורד               35
# 695      רעננה      דירה       4 חד׳  110.0            קזן              NaN
# 696      רעננה     קוטג'       7 חד׳  376.0         הטללים              NaN
# 697      רעננה      דירה       5 חד׳  126.0        אחד העם              NaN
# 698      רעננה      דירה     4.5 חד׳  140.0            קזן               10
#
#             city_area      price  num_of_images     floor_out_of  ...  \
# 0    אם המושבות החדשה  3600000.0            6.0  קומה 11 מתוך 19  ...
# 1             נווה גן  2550000.0            6.0    קומה 6 מתוך 9  ...
# 2     קרית הרב סלומון  2650000.0           10.0    קומה 2 מתוך 7  ...
# 3          המרכז השקט  2450000.0            8.0    קומה 2 מתוך 6  ...
# 4          כפר גנים ב  2720000.0            9.0    קומה 3 מתוך 6  ...
# ..                ...        ...            ...              ...  ...
# 694              2005  8200000.0            NaN    קומה 4 מתוך 4  ...
# 695         מרכז דרום  3350000.0            6.0    קומה 4 מתוך 6  ...
# 696         קרית גנים  8500000.0           13.0        קומת קרקע  ...
# 697              לסטר  3850000.0            NaN    קומה 5 מתוך 7  ...
# 698         מרכז דרום  3730000.0            6.0    קומה 3 מתוך 6  ...
#
#     hasStorage  condition  hasAirCondition  hasBalcony  hasMamad   \
# 0         False       שמור             True       False      True
# 1          True       שמור             True       False      True
# 2          True        חדש             True        True      True
# 3         False      משופץ             True       False      True
# 4         False      משופץ             True        True      True
# ..          ...        ...              ...         ...       ...
# 694     יש מחסן       שמור    יש מיזוג אויר    יש מרפסת   יש ממ״ד
# 695     יש מחסן        חדש    יש מיזוג אויר    יש מרפסת   יש ממ״ד
# 696    אין מחסן        חדש   אין מיזוג אויר   אין מרפסת  אין ממ״ד
# 697    אין מחסן        חדש    יש מיזוג אויר    יש מרפסת   יש ממ״ד
# 698     יש מחסן      משופץ    יש מיזוג אויר    יש מרפסת   יש ממ״ד
#
#     handicapFriendly         entranceDate  furniture  publishedDays   \
# 0                True                 גמיש   לא צויין              7
# 1               False                מיידי   לא צויין              8
# 2               False                 גמיש       חלקי              6
# 3                True                 גמיש       חלקי              8
# 4                True                 גמיש   לא צויין             21
# ..                ...                  ...        ...            ...
# 694     לא נגיש לנכים                 גמיש        אין            NaN
# 695        נגיש לנכים                 גמיש   לא צויין            NaN
# 696     לא נגיש לנכים  2023-08-01 00:00:00   לא צויין            NaN
# 697        נגיש לנכים                מיידי   לא צויין            NaN
# 698        נגיש לנכים  2024-02-01 00:00:00   לא צויין            NaN
#
#                                           description
# 0    למכירה 5.5 חדרים ענקית, מרווחת , מוארת , קומה ...
# 1    למכירה מפרטי ברחוב אהרון כצנלסון השקט והמבוקש,...
# 2    פריים לוקשיין בשכונת שיפר המאוד מבוקשת!!! למכי...
# 3    בפתח תקווה ברחוב שמואל סלנט המבוקש,לא כדאי לפס...
# 4    הדירה משופצת חלקית בטעם טוב , פונה לעורף לכיוו...
# ..                                                 ...
# 694   בית גדול מאוד , 3 כיווני אוויר , 2 מרפסות גדולות
# 695  בקומה 4 הדירה 110 מ"ר נטו136 מ"ר ארנונה.מעוצבת...
# 696  במערב המבוקש! !ה---- בית הנדיר הזה הוא עוד אחד...
# 697  דירה חדשה מהקבלן באזור מבוקש .\n5 חדרים .מרווח...
# 698  לא למתווכים!, ללא תיווך!, מתווכים לא להתקשר! ד...
#
# [694 rows x 23 columns]

# %%
def only_digits(value):
    if isinstance(value, float):
        return value
    elif isinstance(value, str):
        numbers = ''.join(filter(lambda x: x.isdigit() or x == '.', value))
        if numbers:
            return float(numbers)
    return value
data_filter['room_number'] = data_filter['room_number'].apply(only_digits)
data_filter.head()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_12836\3019604288.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_filter['room_number'] = data_filter['room_number'].apply(only_digits)
#         City  type room_number   Area         Street number_in_street  \
# 0  פתח תקווה  דירה         5.5  137.0     רפאלי שרגא                3
# 1  פתח תקווה  דירה           3   84.0  כצנלסון אהרון                6
# 2  פתח תקווה  דירה           4  120.0       הירקונים               17
# 3  פתח תקווה  דירה         3.5  110.0     סלנט שמואל               56
# 4  פתח תקווה  דירה         4.5  120.0    בן צבי יצחק               28
#
#           city_area      price  num_of_images     floor_out_of  ...  \
# 0  אם המושבות החדשה  3600000.0            6.0  קומה 11 מתוך 19  ...
# 1           נווה גן  2550000.0            6.0    קומה 6 מתוך 9  ...
# 2   קרית הרב סלומון  2650000.0           10.0    קומה 2 מתוך 7  ...
# 3        המרכז השקט  2450000.0            8.0    קומה 2 מתוך 6  ...
# 4        כפר גנים ב  2720000.0            9.0    קומה 3 מתוך 6  ...
#
#   hasStorage  condition  hasAirCondition  hasBalcony  hasMamad   \
# 0       False       שמור             True       False      True
# 1        True       שמור             True       False      True
# 2        True        חדש             True        True      True
# 3       False      משופץ             True       False      True
# 4       False      משופץ             True        True      True
#
#   handicapFriendly  entranceDate  furniture  publishedDays   \
# 0              True          גמיש   לא צויין              7
# 1             False         מיידי   לא צויין              8
# 2             False          גמיש       חלקי              6
# 3              True          גמיש       חלקי              8
# 4              True          גמיש   לא צויין             21
#
#                                         description
# 0  למכירה 5.5 חדרים ענקית, מרווחת , מוארת , קומה ...
# 1  למכירה מפרטי ברחוב אהרון כצנלסון השקט והמבוקש,...
# 2  פריים לוקשיין בשכונת שיפר המאוד מבוקשת!!! למכי...
# 3  בפתח תקווה ברחוב שמואל סלנט המבוקש,לא כדאי לפס...
# 4  הדירה משופצת חלקית בטעם טוב , פונה לעורף לכיוו...
#
# [5 rows x 23 columns]

# %%
#Checking that the type of price is integer

for value in data_filter["price"]:
    print(type(value))
# Out:
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>

# %%
#Checking that the type of area is integer

for value in data_filter["Area"]:
    print(type(value))
# Out:
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>

# %% [markdown]
# ### Deleting unnecessary commas or punctuation from the texts in the address, city area, property description, etc.

# %%
data_filter.loc[:, 'Street'] = data_filter["Street"].apply(lambda x: re.sub(r'[^א-ת\s]', '', str(x)))
data_filter.loc[:, 'city_area'] = data_filter["city_area"].apply(lambda x: re.sub(r'[^א-ת\s]', '', str(x)))
data_filter.loc[:, 'description '] = data_filter["description "].apply(lambda x: re.sub(r'[^א-ת0-9\s]', '', str(x)))
data_filter.head(50)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_12836\2546817125.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_filter.loc[:, 'Street'] = data_filter["Street"].apply(lambda x: re.sub(r'[^א-ת\s]', '', str(x)))
# C:\Users\Admin\AppData\Local\Temp\ipykernel_12836\2546817125.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_filter.loc[:, 'city_area'] = data_filter["city_area"].apply(lambda x: re.sub(r'[^א-ת\s]', '', str(x)))
# C:\Users\Admin\AppData\Local\Temp\ipykernel_12836\2546817125.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_filter.loc[:, 'description '] = data_filter["description "].apply(lambda x: re.sub(r'[^א-ת0-9\s]', '', str(x)))
#          City     type room_number   Area           Street number_in_street  \
# 0   פתח תקווה     דירה         5.5  137.0       רפאלי שרגא                3
# 1   פתח תקווה     דירה           3   84.0    כצנלסון אהרון                6
# 2   פתח תקווה     דירה           4  120.0         הירקונים               17
# 3   פתח תקווה     דירה         3.5  110.0       סלנט שמואל               56
# 4   פתח תקווה     דירה         4.5  120.0      בן צבי יצחק               28
# 5   פתח תקווה     דירה           4  120.0         ההסתדרות                2
# 6   פתח תקווה     דירה           4   98.0          רוטשילד               18
# 7   פתח תקווה     דירה         5.5  140.0        רפאל איתן                1
# 8   פתח תקווה     דירה           5  147.0     גיסין אבשלום               23
# 9   פתח תקווה     דירה           4  100.0  אלוף רחבעם זאבי              NaN
# 10  פתח תקווה     דירה           3   75.0        הרב קלישר               27
# 11      נתניה     דירה           4   95.0          שפיגלמן                4
# 12      נתניה     דירה           5  125.0  שדרות לנטוס טום               71
# 13      נתניה     דירה           4  121.0        מנור אהוד                8
# 14      נתניה     דירה           4  100.0           בנימין              NaN
# 15      נתניה     דירה           5  140.0            נתניה                1
# 16      נתניה     דירה           3   55.0         גרינבוים               37
# 17      נתניה  דירת גן           3   70.0           הברבור               17
# 18      נתניה     דירה           3  100.0   מרכז העיר דרום              NaN
# 19      נתניה     דירה           5  145.0       חיטמן עוזי                9
# 20      נתניה  דירת גג           3   62.0             נחום               29
# 21  פתח תקווה    בניין         NaN   93.0             הרצל               85
# 22  פתח תקווה     דירה           3   75.0        הרב קלישר               27
# 23  פתח תקווה     דירה           4  108.0                               NaN
# 24  פתח תקווה     דירה         2.5   49.0  פינס יחיאל מיכל               29
# 25  פתח תקווה     דירה           5  147.0     גיסין אבשלום               23
# 26  פתח תקווה     דירה           6  150.0            מסקין               46
# 27  פתח תקווה     דירה           4   95.0              קיש              NaN
# 28  פתח תקווה     דירה           5  130.0                               NaN
# 29  פתח תקווה     דירה           4  104.0          רום יעל               13
# 30  פתח תקווה     דירה           4  100.0                               NaN
# 31  פתח תקווה     דירה           4  120.0        גובר רבקה                9
# 32  פתח תקווה     דירה           4  100.0   שפירא הרמן צבי                7
# 33  פתח תקווה     דירה           6    NaN       טבצניק דוד              NaN
# 34  פתח תקווה     דירה           3   78.0       זכרון יעקב               46
# 35  פתח תקווה    קוטג'           8  270.0          ה באייר               15
# 36  פתח תקווה     דירה           4   90.0           הוז דב                4
# 37  פתח תקווה     דירה           4   96.0        לבון פנחס              NaN
# 38  פתח תקווה     דירה           6  140.0                               NaN
# 39  פתח תקווה     דירה           5  135.0         מבצע דקל               13
# 40  פתח תקווה     דירה         3.5   80.0         סמילנסקי               15
# 41  פתח תקווה     דירה           5  118.0                               NaN
# 42  פתח תקווה     דירה           5  119.0      בן צבי יצחק              NaN
# 43  פתח תקווה     דירה           4   96.0            הזוהר               26
# 44  פתח תקווה     דירה           4  118.0  אלוף רחבעם זאבי                7
# 45    באר שבע     דירה           5  148.0       עוזי נרקיס                8
# 46    באר שבע     דירה           2   52.0      אליהו הנביא                2
# 47    באר שבע     דירה           2   54.0        רחבת חי ל              NaN
# 48    באר שבע    קוטג'           6  182.0         שמחת כהן              NaN
# 49    באר שבע     דירה           4  120.0            מרווה               14
#
#              city_area      price  num_of_images     floor_out_of  ...  \
# 0     אם המושבות החדשה  3600000.0            6.0  קומה 11 מתוך 19  ...
# 1              נווה גן  2550000.0            6.0    קומה 6 מתוך 9  ...
# 2      קרית הרב סלומון  2650000.0           10.0    קומה 2 מתוך 7  ...
# 3           המרכז השקט  2450000.0            8.0    קומה 2 מתוך 6  ...
# 4           כפר גנים ב  2720000.0            9.0    קומה 3 מתוך 6  ...
# 5            מרכז העיר  2550000.0            3.0    קומה 3 מתוך 6  ...
# 6                 קרול  2640000.0            5.0    קומה 6 מתוך 8  ...
# 7     אם המושבות החדשה  3650000.0            5.0   קומה 7 מתוך 24  ...
# 8              נווה גן  3400000.0            4.0  קומה 11 מתוך 14  ...
# 9     אם המושבות החדשה  2980000.0            7.0    קומה 2 מתוך 9  ...
# 10          מחנה יהודה  2100000.0            4.0    קומה 2 מתוך 6  ...
# 11         קרית השרון   2620000.0            0.0    קומה 4 מתוך 9  ...
# 12         קרית השרון   3500000.0            0.0  קומה 13 מתוך 16  ...
# 13           עיר ימים   4500000.0            7.0   קומה 9 מתוך 21  ...
# 14     מרכז העיר דרום   2230000.0            6.0    קומה 4 מתוך 6  ...
# 15         נוף הטיילת   4250000.0            0.0  קומה 14 מתוך 28  ...
# 16           נאות שקד   1580000.0            4.0    קומה 2 מתוך 3  ...
# 17          קרית רבין   2150000.0           11.0        קומת קרקע  ...
# 18     מרכז העיר דרום   1890000.0            5.0    קומה 4 מתוך 3  ...
# 19           עיר ימים   4800000.0            8.0        קומת קרקע  ...
# 20           רמת ידין   1370000.0            0.0    קומה 3 מתוך 3  ...
# 21          המרכז השקט  1950000.0            5.0   קומה 2 מתוך 4   ...
# 22          מחנה יהודה  2100000.0            1.0    קומה 2 מתוך 2  ...
# 23          המרכז השקט  2490000.0            0.0    קומה 3 מתוך 6  ...
# 24          המרכז השקט  1575000.0            0.0    קומה 3 תוך 19  ...
# 25             נווה גן  3400000.0            5.0    קומה 6 מתוך 9  ...
# 26          כפר גנים ג  4347000.0            3.0    קומה 1 מתוך 7  ...
# 27               אחדות  2250000.0            6.0   קומה 7 מתוך 16  ...
# 28          כפר גנים ג  3650000.0            0.0    קומה 1 מתוך 7  ...
# 29    אם המושבות החדשה  3150000.0            0.0   קומה 7 מתוך 16  ...
# 30             נווה גן  2660000.0            0.0    קומה 1 מתוך 7  ...
# 31    אם המושבות החדשה  3190000.0            0.0   קומה 7 מתוך 10  ...
# 32          המרכז השקט  2450000.0            0.0    קומה 1 מתוך 7  ...
# 33             נווה גן  3390000.0            9.0   קומה 9 מתוך 16  ...
# 34   אם המושבות הותיקה  2550000.0            3.0    קומה 1 מתוך 7  ...
# 35     קרית אליעזר פרי  5700000.0            2.0        קומת קרקע  ...
# 36          כפר גנים א  2200000.0            1.0    קומה 2 מתוך 2  ...
# 37          כפר גנים ב  2320000.0            8.0    קומה 4 מתוך 6  ...
# 38             נווה גן  3690000.0            7.0    קומה 3 תוך 19  ...
# 39             נווה גן  3800000.0            3.0    קומה 7 מתוך 9  ...
# 40          המרכז השקט  2200000.0            9.0   קומה 1 מתוך 10  ...
# 41             נווה גן  3130000.0            7.0   קומה 3 מתוך 10  ...
# 42          כפר גנים ב  2850000.0            5.0    קומה 2 מתוך 8  ...
# 43          מחנה יהודה  2270000.0            3.0    קומה 1 מתוך 7  ...
# 44    אם המושבות החדשה  3200000.0            1.0   קומה 7 מתוך 16  ...
# 45             רמות ב   1890000.0            4.0    קומה 3 מתוך 5  ...
# 46            שכונה ד    540000.0           10.0        קומת קרקע  ...
# 47            שכונה ו    650000.0            7.0    קומה 2 מתוך 4  ...
# 48            שכונה ו   2750000.0           19.0        קומת קרקע  ...
# 49            שכונה ב   1730000.0           10.0    קומה 4 מתוך 6  ...
#
#    hasStorage  condition  hasAirCondition  hasBalcony  hasMamad   \
# 0        False       שמור             True       False      True
# 1         True       שמור             True       False      True
# 2         True        חדש             True        True      True
# 3        False      משופץ             True       False      True
# 4        False      משופץ             True        True      True
# 5        False      משופץ             True       False     False
# 6        False       שמור             True        True     False
# 7         True      משופץ             True       False      True
# 8         True        חדש             True        True      True
# 9        False        חדש             True        True      True
# 10       False       שמור             True        True      True
# 11       False      משופץ             True       False      True
# 12        True      משופץ             True       False      True
# 13        True      משופץ             True        True      True
# 14       False      משופץ             True       False      True
# 15        True        חדש             True       False      True
# 16       False      משופץ             True       False     False
# 17       False       שמור             True        True      True
# 18       False       שמור             True        True     False
# 19        True      משופץ             True       False      True
# 20       False      משופץ             True       False     False
# 21        True        חדש             True       False      True
# 22        True        חדש             True        True      True
# 23       False      משופץ            False        True      True
# 24       False      משופץ             True       False      True
# 25       False      משופץ             True       False     False
# 26       False      משופץ            False        True     False
# 27        True      משופץ            False       False     False
# 28        True       שמור             True        True      True
# 29       False      משופץ             True        True      True
# 30       False      משופץ            False       False     False
# 31        True      משופץ            False        True     False
# 32        True      משופץ             True        True      True
# 33       False      משופץ             True       False      True
# 34       False      משופץ             True       False      True
# 35       False       שמור             True        True      True
# 36       False      משופץ            False        True     False
# 37        True      משופץ            False        True     False
# 38        True      משופץ             True        True     False
# 39       False   לא צויין             True       False      True
# 40        True        חדש             True        True      True
# 41       False        חדש             True        True     False
# 42        True      משופץ            False       False     False
# 43        True      משופץ            False       False      True
# 44        True      משופץ             True        True      True
# 45       False      משופץ             True        True      True
# 46       False      משופץ             True       False     False
# 47       False        חדש             True       False     False
# 48        True        חדש             True        True      True
# 49       False        חדש             True        True      True
#
#    handicapFriendly         entranceDate  furniture  publishedDays   \
# 0               True                 גמיש   לא צויין              7
# 1              False                מיידי   לא צויין              8
# 2              False                 גמיש       חלקי              6
# 3               True                 גמיש       חלקי              8
# 4               True                 גמיש   לא צויין             21
# 5               True                 גמיש       חלקי              8
# 6              False                 גמיש   לא צויין              9
# 7              False                 גמיש   לא צויין              9
# 8               True                מיידי        אין             10
# 9               True  2023-07-01 00:00:00   לא צויין            60+
# 10             False                 גמיש       חלקי             10
# 11             False             לא צויין   לא צויין          None
# 12              True             לא צויין   לא צויין          None
# 13              True                 גמיש   לא צויין          None
# 14              True                 גמיש   לא צויין          None
# 15             False             לא צויין   לא צויין          None
# 16             False                 גמיש   לא צויין          None
# 17             False                מיידי   לא צויין          None
# 18             False                מיידי   לא צויין          None
# 19             False                 גמיש       חלקי          None
# 20             False             לא צויין   לא צויין          None
# 21              True                מיידי        מלא            NaN
# 22              True  2023-11-01 00:00:00        מלא            NaN
# 23              True                מיידי   לא צויין            NaN
# 24             False                מיידי   לא צויין            NaN
# 25              True                 גמיש   לא צויין            NaN
# 26              True             לא צויין       חלקי            NaN
# 27             False             לא צויין   לא צויין            NaN
# 28             False                מיידי   לא צויין            NaN
# 29             False             לא צויין   לא צויין            NaN
# 30              True  2023-12-01 00:00:00   לא צויין            NaN
# 31             False                מיידי   לא צויין            NaN
# 32             False                מיידי   לא צויין            NaN
# 33             False                 גמיש       חלקי            NaN
# 34             False             לא צויין   לא צויין            NaN
# 35             False             לא צויין   לא צויין            NaN
# 36             False                מיידי   לא צויין            NaN
# 37              True  2023-06-01 00:00:00   לא צויין            NaN
# 38              True                מיידי   לא צויין            NaN
# 39             False                מיידי   לא צויין            NaN
# 40             False                 גמיש   לא צויין            NaN
# 41             False             לא צויין   לא צויין            NaN
# 42             False             לא צויין   לא צויין            NaN
# 43              True                מיידי       חלקי            NaN
# 44              True  2023-01-01 00:00:00   לא צויין            NaN
# 45              True                 גמיש        אין            NaN
# 46              True                 גמיש       חלקי            NaN
# 47             False             לא צויין   לא צויין            NaN
# 48              True                 גמיש   לא צויין            NaN
# 49              True                 גמיש   לא צויין            NaN
#
#                                          description
# 0   למכירה 55 חדרים ענקית מרווחת  מוארת  קומה גבוה...
# 1   למכירה מפרטי ברחוב אהרון כצנלסון השקט והמבוקש ...
# 2   פריים לוקשיין בשכונת שיפר המאוד מבוקשת למכירה ...
# 3   בפתח תקווה ברחוב שמואל סלנט המבוקשלא כדאי לפספ...
# 4   הדירה משופצת חלקית בטעם טוב  פונה לעורף לכיוון...
# 5   במיקום מצוין  דירה ענקית משופצת ויפיפייה חניה ...
# 6   דירה ענקית ומרווחת  קומה 6 כיוון כללי מערב  לל...
# 7   דירה מרווחת מוארת וענקית שמרגישים מהרגע הראשון...
# 8   למכירה דירה חדשה בפרויקט היוקרתי של קטה נווה ג...
# 9   במיקום הטוב באם המושבות דירת 4 חדרים מיוחדת בת...
# 10  2 חניות דירה שמורה ויפה מלאת אור ברחוב מבוקש מ...
# 11  דירה משופצת במיקום מעולה אחלה שכנים מטבח מנגר ...
# 12                         למכירה דירה קומה 13 בנתניה
# 13  דירה משגעת עם נוף ים על קו החוף בעיר ימים במיק...
# 14  למכירה בבלעדיות במרכז העיר לב העיר התוסס במיקו...
# 15  ללא תיווך ירדה מהתנהלות ופנוייה למגורים  בניין...
# 16  מעולה להשקעה רק 15 דק הליכה לים שופצה לפני שנה...
# 17
# 18  למכירה במרכז נתניה דירת 35 חדרים גדולה מרגיש כ...
# 19  מפרטי בקומפלקס יחודי בעיר ימים עם בריכת שחייה ...
# 20  דירה מתוקה 62 מ קומה 3 2 חדרי שינה סלון מרווח ...
# 21  דירת מרווחת ומוארת במצב מצוין מרפסת עם נוף נהד...
# 22  דירת מרווחת ומוארת במצב מצוין 3 חדרים גדולים ב...
# 23  דירת מרווחת ומוארת במצב מצוין 4 חדרים גדולים מ...
# 24  דירת מרווחת ומוארת במצב מצוין 25 חדרים גדולים ...
# 25  דירת מרווחת ומוארת במצב מצוין 5 חדרים גדולים מ...
# 26
# 27
# 28
# 29
# 30                מרפסת עם נוף נהדר בשכונה שקטה ונוחה
# 31  דירת מרווחת ומוארת במצב מצוין 4 חדרים גדולים מ...
# 32  דירת מרווחת ומוארת במצב מצוין 4 חדרים גדולים מ...
# 33  דירת מרווחת ומוארת במצב מצוין 6 חדרים גדולים מ...
# 34  דירת מרווחת ומוארת במצב מצוין 3 חדרים גדולים מ...
# 35  דירת מרווחת ומוארת במצב מצוין 8 חדרים גדולים מ...
# 36  דירת מרווחת ומוארת במצב מצוין 4 חדרים גדולים מ...
# 37  דירת מרווחת ומוארת במצב מצוין 4 חדרים גדולים מ...
# 38  דירת מרווחת ומוארת במצב מצוין 6 חדרים גדולים מ...
# 39  דירת מרווחת ומוארת במצב מצוין 5 חדרים גדולים מ...
# 40  דירת מרווחת ומוארת במצב מצוין 35 חדרים גדולים ...
# 41
# 42
# 43
# 44  דירת מרווחת ומוארת במצב מצוין 4 חדרים גדולים מ...
# 45  מה זמן אתם כבר מחפשים דירת 5 חדרים למכירה ברמו...
# 46  דירת מקסימה ומוארת בת 2 חדרים בארנונה 5267 כול...
# 47  רחבת החילו חדשה\nפצצה להשקעה מגורים\n2 חדרים 5...
# 48  למהירי  החלטה נכס מדהים שלא יוצא כל  יום בקריה...
# 49
#
# [50 rows x 23 columns]

# %% [markdown]
# ### Representing all boolean fields as zeros and ones.

# %%
mapping = {
    'שמור': 1, 'חדש': 1, 'משופץ': 1, 'חדש מקבלן': 1, 'מצב הנכס:משופץ': 1, 'מצב הנכס:שמור': 1,
    'מצב הנכס:חדש': 1, 'מצב הנכס:חדש מקבלן': 1, 'Save': 1, 'new': 1, 'renovated': 1, 'כן': 1,
    'יש מחסן': 1, 'יש סורגים': 1, 'יש חניה': 1, 'יש חנייה': 1, 'יש מעלית': 1, 'יש מיזוג אוויר': 1,'יש מיזוג אויר': 1, 'יש מרפסת': 1,
    'נגיש לנכים': 1, 'יש': 1,'אין':0, 'נגיש': 1, 'יש ממ"ד': 1,'יש ממ״ד': 1, 'יש מיזוג אויר': 1, 'yes': 1,
    'לא צויין': 0, 'מצב הנכס:לא צויין': 0, 'ישן': 0, 'לא': 0, 'אין ממ"ד': 0,'דורש שיפוץ': 0, 'לא נגיש לנכים': 0,
    'אין ממ״ד': 0, 'אין מרפסת': 0, 'אין מחסן': 0, 'אין סורגים': 0, 'אין חניה': 0, 'אין מעלית': 0,
    'אין מיזוג אויר': 0, 'no': 0, 'לא נגיש': 0,
    True: 1, False: 0  # Mapping True to 1 and False to 0
}
columns_to_map = ['hasElevator ', 'hasParking ', 'hasBars ','hasStorage ','hasAirCondition ','hasBalcony ','hasMamad ','handicapFriendly ']  # List of columns to map
data_filter[columns_to_map] = data_filter[columns_to_map].replace(mapping)
data_filter.tail()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_12836\1378775890.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_filter[columns_to_map] = data_filter[columns_to_map].replace(mapping)
#       City      type room_number   Area   Street number_in_street  city_area  \
# 694  רעננה  בית פרטי         9.5  350.0     הורד               35
# 695  רעננה      דירה         4.0  110.0      קזן              NaN  מרכז דרום
# 696  רעננה     קוטג'         7.0  376.0   הטללים              NaN  קרית גנים
# 697  רעננה      דירה         5.0  126.0  אחד העם              NaN       לסטר
# 698  רעננה      דירה         4.5  140.0      קזן               10  מרכז דרום
#
#          price  num_of_images   floor_out_of  ...  hasStorage   condition   \
# 694  8200000.0            NaN  קומה 4 מתוך 4  ...          1.0        שמור
# 695  3350000.0            6.0  קומה 4 מתוך 6  ...          1.0         חדש
# 696  8500000.0           13.0      קומת קרקע  ...          0.0         חדש
# 697  3850000.0            NaN  קומה 5 מתוך 7  ...          0.0         חדש
# 698  3730000.0            6.0  קומה 3 מתוך 6  ...          1.0       משופץ
#
#      hasAirCondition   hasBalcony  hasMamad   handicapFriendly   \
# 694               1.0          1.0       1.0                0.0
# 695               1.0          1.0       1.0                1.0
# 696               0.0          0.0       0.0                0.0
# 697               1.0          1.0       1.0                1.0
# 698               1.0          1.0       1.0                1.0
#
#            entranceDate   furniture   publishedDays   \
# 694                 גמיש         אין             NaN
# 695                 גמיש    לא צויין             NaN
# 696  2023-08-01 00:00:00    לא צויין             NaN
# 697                מיידי    לא צויין             NaN
# 698  2024-02-01 00:00:00    לא צויין             NaN
#
#                                           description
# 694     בית גדול מאוד  3 כיווני אוויר  2 מרפסות גדולות
# 695  בקומה 4 הדירה 110 מר נטו136 מר ארנונהמעוצבת לה...
# 696  במערב המבוקש ה בית הנדיר הזה הוא עוד אחד מה הי...
# 697  דירה חדשה מהקבלן באזור מבוקש \n5 חדרים מרווחת ...
# 698  לא למתווכים ללא תיווך מתווכים לא להתקשר דירה ע...
#
# [5 rows x 23 columns]

# %% [markdown]
# ## Added Floor and Total Floors columns

# %%
import re
import numpy as np

lines = data_filter["floor_out_of"].fillna('').values

new_column = ['floor']
total_floors_column = []

for line in lines:
    match = re.findall(r'\d+', str(line))
    if len(match) >= 2:
        new_column.append(match[0])
        total_floors_column.append(match[1])
    else:
        new_column.append(np.nan)
        total_floors_column.append(np.nan)

# Check for length mismatch
if len(new_column) > len(data_filter):
    new_column = new_column[:len(data_filter)]
if len(total_floors_column) > len(data_filter):
    total_floors_column = total_floors_column[:len(data_filter)]

# Add the new columns to the DataFrame
data_filter['floor'] = new_column
data_filter['total_floors'] = total_floors_column
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_12836\2054017108.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_filter['floor'] = new_column
# C:\Users\Admin\AppData\Local\Temp\ipykernel_12836\2054017108.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_filter['total_floors'] = total_floors_column

# %%
import numpy as np

lines = data_filter["floor_out_of"].fillna('').values

new_column = []

for line in lines:
    if "קומת קרקע" in line:
        new_column.append('0')
    else:
        match = re.search(r'\d+', str(line))
        if match:
            new_column.append(match.group())
        else:
            new_column.append(np.nan)

# Adjust the length of new_column to match the DataFrame index
missing_entries = len(data_filter) - len(new_column)
new_column += [np.nan] * missing_entries

# Change the first element in the new_column with the first number from "floor_out_of" column
first_floor_out_of = data_filter["floor_out_of"].fillna('').values[0]
match = re.search(r'\d+', str(first_floor_out_of))
if match:
    new_column[0] = match.group()

# Add the new column to the DataFrame
data_filter['floor'] = new_column

data_filter.head()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_12836\1258361591.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_filter['floor'] = new_column
#         City  type room_number   Area         Street number_in_street  \
# 0  פתח תקווה  דירה         5.5  137.0     רפאלי שרגא                3
# 1  פתח תקווה  דירה           3   84.0  כצנלסון אהרון                6
# 2  פתח תקווה  דירה           4  120.0       הירקונים               17
# 3  פתח תקווה  דירה         3.5  110.0     סלנט שמואל               56
# 4  פתח תקווה  דירה         4.5  120.0    בן צבי יצחק               28
#
#           city_area      price  num_of_images     floor_out_of  ...  \
# 0  אם המושבות החדשה  3600000.0            6.0  קומה 11 מתוך 19  ...
# 1           נווה גן  2550000.0            6.0    קומה 6 מתוך 9  ...
# 2   קרית הרב סלומון  2650000.0           10.0    קומה 2 מתוך 7  ...
# 3        המרכז השקט  2450000.0            8.0    קומה 2 מתוך 6  ...
# 4        כפר גנים ב  2720000.0            9.0    קומה 3 מתוך 6  ...
#
#    hasAirCondition   hasBalcony   hasMamad   handicapFriendly  entranceDate   \
# 0               1.0          0.0        1.0                1.0          גמיש
# 1               1.0          0.0        1.0                0.0         מיידי
# 2               1.0          1.0        1.0                0.0          גמיש
# 3               1.0          0.0        1.0                1.0          גמיש
# 4               1.0          1.0        1.0                1.0          גמיש
#
#    furniture   publishedDays   \
# 0    לא צויין               7
# 1    לא צויין               8
# 2        חלקי               6
# 3        חלקי               8
# 4    לא צויין              21
#
#                                         description   floor total_floors
# 0  למכירה 55 חדרים ענקית מרווחת  מוארת  קומה גבוה...     11           19
# 1  למכירה מפרטי ברחוב אהרון כצנלסון השקט והמבוקש ...      6            9
# 2  פריים לוקשיין בשכונת שיפר המאוד מבוקשת למכירה ...      2            7
# 3  בפתח תקווה ברחוב שמואל סלנט המבוקשלא כדאי לפספ...      2            6
# 4  הדירה משופצת חלקית בטעם טוב  פונה לעורף לכיוון...      3            6
#
# [5 rows x 25 columns]

# %% [markdown]
# ### Updating the entrance_date column by categories

# %%
data_filter['entranceDate '] = data_filter['entranceDate '].replace('גמיש', 'flexible')
data_filter['entranceDate '] = data_filter['entranceDate '].replace('לא צויין', 'not_defined')
data_filter['entranceDate '] = data_filter['entranceDate '].replace('מיידי', 'Now')
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_12836\3247019813.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_filter['entranceDate '] = data_filter['entranceDate '].replace('גמיש', 'flexible')
# C:\Users\Admin\AppData\Local\Temp\ipykernel_12836\3247019813.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_filter['entranceDate '] = data_filter['entranceDate '].replace('לא צויין', 'not_defined')
# C:\Users\Admin\AppData\Local\Temp\ipykernel_12836\3247019813.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_filter['entranceDate '] = data_filter['entranceDate '].replace('מיידי', 'Now')

# %%
valid_values = ['flexible', 'not_defined', 'Now']

conversion_dict = {value: pd.to_datetime(value, errors='coerce') for value in valid_values}

data_filter['entranceDate '] = data_filter['entranceDate '].map(conversion_dict).fillna(data_filter['entranceDate '])

# Retrieve the current date
current_date = pd.to_datetime('today').normalize()


# Iterate through each row
for index, row in data_filter.iterrows():
    if pd.isnull(row['entranceDate ']) or pd.isna(row['entranceDate ']):
        continue  # Skip rows with missing or NaT values
    elif isinstance(row['entranceDate '], str):
        continue  # Skip rows with string values
    else:
        # Calculate the duration in months
        duration = (row['entranceDate '].year - current_date.year) * 12 + (row['entranceDate '].month - current_date.month)
        
        # Assign category based on duration
        if duration < 6:
            category = 'less_than_6 months'
        elif 6 <= duration <= 12:
            category = 'months_6_12'
        else:
            category = 'above_year'

    # Update the row with the assigned category
    data_filter.at[index, 'entranceDate '] = category
data_filter.tail()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_12836\3094890446.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_filter['entranceDate '] = data_filter['entranceDate '].map(conversion_dict).fillna(data_filter['entranceDate '])
#       City      type room_number   Area   Street number_in_street  city_area  \
# 694  רעננה  בית פרטי         9.5  350.0     הורד               35
# 695  רעננה      דירה         4.0  110.0      קזן              NaN  מרכז דרום
# 696  רעננה     קוטג'         7.0  376.0   הטללים              NaN  קרית גנים
# 697  רעננה      דירה         5.0  126.0  אחד העם              NaN       לסטר
# 698  רעננה      דירה         4.5  140.0      קזן               10  מרכז דרום
#
#          price  num_of_images   floor_out_of  ...  hasAirCondition   \
# 694  8200000.0            NaN  קומה 4 מתוך 4  ...               1.0
# 695  3350000.0            6.0  קומה 4 מתוך 6  ...               1.0
# 696  8500000.0           13.0      קומת קרקע  ...               0.0
# 697  3850000.0            NaN  קומה 5 מתוך 7  ...               1.0
# 698  3730000.0            6.0  קומה 3 מתוך 6  ...               1.0
#
#      hasBalcony   hasMamad   handicapFriendly        entranceDate   \
# 694          1.0        1.0                0.0            flexible
# 695          1.0        1.0                1.0            flexible
# 696          0.0        0.0                0.0  less_than_6 months
# 697          1.0        1.0                1.0                 Now
# 698          1.0        1.0                1.0         months_6_12
#
#      furniture   publishedDays   \
# 694         אין             NaN
# 695    לא צויין             NaN
# 696    לא צויין             NaN
# 697    לא צויין             NaN
# 698    לא צויין             NaN
#
#                                           description   floor total_floors
# 694     בית גדול מאוד  3 כיווני אוויר  2 מרפסות גדולות      4            4
# 695  בקומה 4 הדירה 110 מר נטו136 מר ארנונהמעוצבת לה...      4            6
# 696  במערב המבוקש ה בית הנדיר הזה הוא עוד אחד מה הי...      0          NaN
# 697  דירה חדשה מהקבלן באזור מבוקש \n5 חדרים מרווחת ...      5            7
# 698  לא למתווכים ללא תיווך מתווכים לא להתקשר דירה ע...      3            6
#
# [5 rows x 25 columns]

# %%
data_filter.dtypes
# Out:
# City                  object
# type                  object
# room_number           object
# Area                 float64
# Street                object
# number_in_street      object
# city_area             object
# price                float64
# num_of_images        float64
# floor_out_of          object
# hasElevator          float64
# hasParking           float64
# hasBars              float64
# hasStorage           float64
# condition             object
# hasAirCondition      float64
# hasBalcony           float64
# hasMamad             float64
# handicapFriendly     float64
# entranceDate          object
# furniture             object
# publishedDays         object
# description           object
# floor                 object
# total_floors          object
# dtype: object

# %% [markdown]
# # עד כאן למטלה של ענת - מכאן והלאה וברובץ השניה שבו הכנסנו את שאר הנתונים לפונקציה נמצאת המטלה של חן והפלאסק

# %%
## 1-Central
city_to_region = {
    'פתח תקווה': 'Central',
    'נתניה': 'Central',
    'באר שבע': 'Southern',
    'הרצליה': 'Central',
    'אריאל': 'Judea and Samaria',
    'דימונה': 'Southern',
    'רחובות': 'Central',
    'גבעת שמואל': 'Central',
    'ירושלים': 'Jerusalem',
    'שוהם': 'Central',
    'כפר סבא': 'Central',
    'רעננה': 'Central',
    'נהריה': 'Northern',
    'זכרון יעקב': 'Central',
    'קרית ביאליק': 'Northern',
    'חיפה': 'Northern',
    'הוד השרון': 'Central',
    'תל אביב': 'Tel Aviv',
    'ראשון לציון': 'Central',
    'יהוד מונוסון': 'Central',
    'נס ציונה': 'Central',
    'אילת': 'Southern',
    'חולון': 'Central',
    'מודיעין מכבים רעות': 'Central',
    'צפת': 'Northern',
    'בת ים': 'Tel Aviv',
    'רמת גן': 'Tel Aviv',
    'נוף הגליל': 'Northern',
    'בית שאן': 'Northern'
}
region_to_number = {
    'פתח תקווה': 1,
    'נתניה': 1,
    'באר שבע': 2,
    'הרצליה': 1,
    'אריאל': 3,
    'דימונה': 2,
    'רחובות': 1,
    'גבעת שמואל': 1,
    'ירושלים': 4,
    'שוהם': 1,
    'כפר סבא': 1,
    'רעננה': 1,
    'נהריה': 5,
    'זכרון יעקב': 1,
    'קרית ביאליק': 5,
    'חיפה': 5,
    'הוד השרון': 1,
    'תל אביב': 6,
    'ראשון לציון': 1,
    'יהוד מונוסון': 1,
    'נס ציונה': 1,
    'אילת': 2,
    'חולון': 1,
    'מודיעין מכבים רעות': 1,
    'צפת': 5,
    'בת ים': 6,
    'רמת גן': 6,
    'נוף הגליל': 5,
    'בית שאן': 5
}

data_filter['Region'] = data_filter['City'].map(city_to_region)
data_filter['Region_number'] = data_filter['City'].map(region_to_number)
data_filter.head(100)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_12836\3993554297.py:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_filter['Region'] = data_filter['City'].map(city_to_region)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_12836\3993554297.py:66: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_filter['Region_number'] = data_filter['City'].map(region_to_number)
#           City     type room_number   Area           Street number_in_street  \
# 0    פתח תקווה     דירה         5.5  137.0       רפאלי שרגא                3
# 1    פתח תקווה     דירה           3   84.0    כצנלסון אהרון                6
# 2    פתח תקווה     דירה           4  120.0         הירקונים               17
# 3    פתח תקווה     דירה         3.5  110.0       סלנט שמואל               56
# 4    פתח תקווה     דירה         4.5  120.0      בן צבי יצחק               28
# ..         ...      ...         ...    ...              ...              ...
# 99      דימונה     דירה         5.0  139.0          תל לכיש                4
# 100     דימונה     דירה         4.0  120.0    הרב אברהם קוק               42
# 101     דימונה  דירת גן         3.0   74.0                               NaN
# 102     דימונה     דירה         3.0   79.0       יהודה הלוי              NaN
# 103     דימונה     דירה         4.0   92.0  שלמה אבן גבירול               34
#
#               city_area      price  num_of_images     floor_out_of  ...  \
# 0      אם המושבות החדשה  3600000.0            6.0  קומה 11 מתוך 19  ...
# 1               נווה גן  2550000.0            6.0    קומה 6 מתוך 9  ...
# 2       קרית הרב סלומון  2650000.0           10.0    קומה 2 מתוך 7  ...
# 3            המרכז השקט  2450000.0            8.0    קומה 2 מתוך 6  ...
# 4            כפר גנים ב  2720000.0            9.0    קומה 3 מתוך 6  ...
# ..                  ...        ...            ...              ...  ...
# 99               ממשית   1390000.0            0.0    קומה 2 מתוך 7  ...
# 100               השחר   1650000.0            0.0    קומה 1 מתוך 8  ...
# 101                       900000.0            8.0        קומת קרקע  ...
# 102   חכמי ישראל תשלוז    685000.0            0.0              NaN  ...
# 103   חכמי ישראל תשלוז    750000.0            0.0    קומה 1 מתוך 2  ...
#
#      hasMamad   handicapFriendly   entranceDate   furniture  publishedDays   \
# 0          1.0                1.0       flexible    לא צויין              7
# 1          1.0                0.0            Now    לא צויין              8
# 2          1.0                0.0       flexible        חלקי              6
# 3          1.0                1.0       flexible        חלקי              8
# 4          1.0                1.0       flexible    לא צויין             21
# ..         ...                ...            ...         ...            ...
# 99         1.0                0.0    not_defined    לא צויין             15
# 100        1.0                1.0    not_defined    לא צויין              0
# 101        1.0                1.0       flexible    לא צויין             56
# 102        0.0                0.0    not_defined    לא צויין              0
# 103        0.0                0.0    not_defined    לא צויין             16
#
#                                           description   floor  total_floors  \
# 0    למכירה 55 חדרים ענקית מרווחת  מוארת  קומה גבוה...     11            19
# 1    למכירה מפרטי ברחוב אהרון כצנלסון השקט והמבוקש ...      6             9
# 2    פריים לוקשיין בשכונת שיפר המאוד מבוקשת למכירה ...      2             7
# 3    בפתח תקווה ברחוב שמואל סלנט המבוקשלא כדאי לפספ...      2             6
# 4    הדירה משופצת חלקית בטעם טוב  פונה לעורף לכיוון...      3             6
# ..                                                 ...    ...           ...
# 99   דירת 5 חדרים 127 פלוס 12 מטר מרפסת חניה מול הכ...      2             7
# 100  דירה חדשה ומשודרגת מקבלןמזגן מיני מרכזי כולל ה...      1             8
# 101  דירת גן בתשלוז 3 חדרים74 מר ארנונהמשופצתמושכרת...      0           NaN
# 102                                                       NaN           NaN
# 103  מעולה למשקיעים יש שוכר לטווח ארוך ב2800 שח יש ...      1             2
#
#        Region Region_number
# 0     Central             1
# 1     Central             1
# 2     Central             1
# 3     Central             1
# 4     Central             1
# ..        ...           ...
# 99   Southern             2
# 100  Southern             2
# 101  Southern             2
# 102  Southern             2
# 103  Southern             2
#
# [100 rows x 27 columns]

# %%
import pandas as pd

# Assuming your DataFrame is called df and the city column is named 'city'
types = data_filter['type']

# Assigning unique numbers to each city
city_codes, unique_cities = pd.factorize(types)

# Creating a new column with the city codes
data_filter['type_num'] = city_codes

# Printing the updated DataFrame
data_filter
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_12836\478690052.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_filter['type_num'] = city_codes
#           City      type room_number   Area         Street number_in_street  \
# 0    פתח תקווה      דירה         5.5  137.0     רפאלי שרגא                3
# 1    פתח תקווה      דירה           3   84.0  כצנלסון אהרון                6
# 2    פתח תקווה      דירה           4  120.0       הירקונים               17
# 3    פתח תקווה      דירה         3.5  110.0     סלנט שמואל               56
# 4    פתח תקווה      דירה         4.5  120.0    בן צבי יצחק               28
# ..         ...       ...         ...    ...            ...              ...
# 694      רעננה  בית פרטי         9.5  350.0           הורד               35
# 695      רעננה      דירה         4.0  110.0            קזן              NaN
# 696      רעננה     קוטג'         7.0  376.0         הטללים              NaN
# 697      רעננה      דירה         5.0  126.0        אחד העם              NaN
# 698      רעננה      דירה         4.5  140.0            קזן               10
#
#             city_area      price  num_of_images     floor_out_of  ...  \
# 0    אם המושבות החדשה  3600000.0            6.0  קומה 11 מתוך 19  ...
# 1             נווה גן  2550000.0            6.0    קומה 6 מתוך 9  ...
# 2     קרית הרב סלומון  2650000.0           10.0    קומה 2 מתוך 7  ...
# 3          המרכז השקט  2450000.0            8.0    קומה 2 מתוך 6  ...
# 4          כפר גנים ב  2720000.0            9.0    קומה 3 מתוך 6  ...
# ..                ...        ...            ...              ...  ...
# 694                    8200000.0            NaN    קומה 4 מתוך 4  ...
# 695         מרכז דרום  3350000.0            6.0    קומה 4 מתוך 6  ...
# 696         קרית גנים  8500000.0           13.0        קומת קרקע  ...
# 697              לסטר  3850000.0            NaN    קומה 5 מתוך 7  ...
# 698         מרכז דרום  3730000.0            6.0    קומה 3 מתוך 6  ...
#
#      handicapFriendly        entranceDate   furniture   publishedDays   \
# 0                  1.0            flexible    לא צויין               7
# 1                  0.0                 Now    לא צויין               8
# 2                  0.0            flexible        חלקי               6
# 3                  1.0            flexible        חלקי               8
# 4                  1.0            flexible    לא צויין              21
# ..                 ...                 ...         ...             ...
# 694                0.0            flexible         אין             NaN
# 695                1.0            flexible    לא צויין             NaN
# 696                0.0  less_than_6 months    לא צויין             NaN
# 697                1.0                 Now    לא צויין             NaN
# 698                1.0         months_6_12    לא צויין             NaN
#
#                                           description   floor  total_floors  \
# 0    למכירה 55 חדרים ענקית מרווחת  מוארת  קומה גבוה...     11            19
# 1    למכירה מפרטי ברחוב אהרון כצנלסון השקט והמבוקש ...      6             9
# 2    פריים לוקשיין בשכונת שיפר המאוד מבוקשת למכירה ...      2             7
# 3    בפתח תקווה ברחוב שמואל סלנט המבוקשלא כדאי לפספ...      2             6
# 4    הדירה משופצת חלקית בטעם טוב  פונה לעורף לכיוון...      3             6
# ..                                                 ...    ...           ...
# 694     בית גדול מאוד  3 כיווני אוויר  2 מרפסות גדולות      4             4
# 695  בקומה 4 הדירה 110 מר נטו136 מר ארנונהמעוצבת לה...      4             6
# 696  במערב המבוקש ה בית הנדיר הזה הוא עוד אחד מה הי...      0           NaN
# 697  דירה חדשה מהקבלן באזור מבוקש \n5 חדרים מרווחת ...      5             7
# 698  לא למתווכים ללא תיווך מתווכים לא להתקשר דירה ע...      3             6
#
#       Region  Region_number type_num
# 0    Central              1        0
# 1    Central              1        0
# 2    Central              1        0
# 3    Central              1        0
# 4    Central              1        0
# ..       ...            ...      ...
# 694  Central              1        5
# 695  Central              1        0
# 696  Central              1        4
# 697  Central              1        0
# 698  Central              1        0
#
# [694 rows x 28 columns]

# %%
grouped_data1 = data_filter.groupby(['type', 'type_num']).size().reset_index(name='count')
grouped_data1.sort_values(by='type_num')
# Out:
#             type  type_num  count
# 5           דירה         0    513
# 7        דירת גן         1     57
# 6        דירת גג         2     10
# 2          בניין         3      3
# 14         קוטג'         4     12
# 1       בית פרטי         5     24
# 4         דופלקס         6     18
# 8      דירת נופש         7      1
# 13       פנטהאוז         8     20
# 15    קוטג' טורי         9      2
# 11  מיני פנטהאוז        10      3
# 10          מגרש        11      3
# 3      דו משפחתי        12     25
# 0            אחר        13      1
# 9        טריפלקס        14      1
# 12          נחלה        15      1

# %%
data_filter.dtypes
# Out:
# City                  object
# type                  object
# room_number           object
# Area                 float64
# Street                object
# number_in_street      object
# city_area             object
# price                float64
# num_of_images        float64
# floor_out_of          object
# hasElevator          float64
# hasParking           float64
# hasBars              float64
# hasStorage           float64
# condition             object
# hasAirCondition      float64
# hasBalcony           float64
# hasMamad             float64
# handicapFriendly     float64
# entranceDate          object
# furniture             object
# publishedDays         object
# description           object
# floor                 object
# total_floors          object
# Region                object
# Region_number          int64
# type_num               int64
# dtype: object

# %%
selected_columns = ['Region_number', 'type_num', 'room_number', 'Area', 'price', 'floor', 'hasElevator ', 'hasParking ' , 'hasBars ','hasStorage ','condition ',
                    'hasAirCondition ','hasBalcony ', 'hasMamad ', 'handicapFriendly ', 'furniture ']

# Create a new DataFrame using the selected columns from the original DataFrame
new_df = data_filter[selected_columns].copy()
new_df = new_df.dropna(subset=["price"])

# Print the new DataFrame
new_df.head()
# Out:
#    Region_number  type_num room_number   Area      price floor  hasElevator   \
# 0              1         0         5.5  137.0  3600000.0    11           1.0
# 1              1         0           3   84.0  2550000.0     6           1.0
# 2              1         0           4  120.0  2650000.0     2           1.0
# 3              1         0         3.5  110.0  2450000.0     2           1.0
# 4              1         0         4.5  120.0  2720000.0     3           1.0
#
#    hasParking   hasBars   hasStorage  condition   hasAirCondition   \
# 0          0.0       1.0          0.0       שמור               1.0
# 1          0.0       1.0          1.0       שמור               1.0
# 2          1.0       1.0          1.0        חדש               1.0
# 3          0.0       1.0          0.0      משופץ               1.0
# 4          1.0       0.0          0.0      משופץ               1.0
#
#    hasBalcony   hasMamad   handicapFriendly  furniture
# 0          0.0        1.0                1.0   לא צויין
# 1          0.0        1.0                0.0   לא צויין
# 2          1.0        1.0                0.0       חלקי
# 3          0.0        1.0                1.0       חלקי
# 4          1.0        1.0                1.0   לא צויין

# %%
# Assuming your DataFrame is named 'df'
#new_df['City'] = new_df['City'].astype(str)
#new_df['type'] = new_df['type'].astype(str)
new_df['condition '] = new_df['condition '].map({'שמור': 1, 'חדש': 1, 'משופץ': 1, 'לא צויין': 0, 'ישן': 0, 'דורש שיפוץ': 0})
new_df['furniture '] = new_df['furniture '].map({'חלקי': 1, 'מלא': 1, 'לא צויין': 0, 'אין': 0})

# %%
new_df['room_number'] = pd.to_numeric(new_df['room_number'], errors='coerce')

# Changing other columns to float type
float_columns = ['Region_number','condition ','furniture ',
                 'type_num', 'room_number', 'Area', 'price', 'floor',
                 'hasElevator ', 'hasParking ', 'hasBars ', 'hasStorage ', 'hasAirCondition ',
                 'hasBalcony ', 'hasMamad ', 'handicapFriendly ']

new_df[float_columns] = new_df[float_columns].astype(float)

# %%
new_df.dtypes
# Out:
# Region_number        float64
# type_num             float64
# room_number          float64
# Area                 float64
# price                float64
# floor                float64
# hasElevator          float64
# hasParking           float64
# hasBars              float64
# hasStorage           float64
# condition            float64
# hasAirCondition      float64
# hasBalcony           float64
# hasMamad             float64
# handicapFriendly     float64
# furniture            float64
# dtype: object

# %%
new_df.loc[new_df["Area"] > 800, "Area"] /= 10
new_df.loc[new_df["room_number"] > 20.0, "room_number"] /= 10

# %%
new_df.describe()
# Out:
#        Region_number    type_num  room_number        Area         price  \
# count     693.000000  693.000000   682.000000  677.000000  6.930000e+02
# mean        2.370851    1.373737     4.320381  122.231905  3.840591e+06
# std         1.889158    3.088343     1.234149   57.291719  1.500778e+07
# min         1.000000    0.000000     1.000000   30.000000  1.000000e+05
# 25%         1.000000    0.000000     3.500000   87.000000  2.120000e+06
# 50%         1.000000    0.000000     4.000000  110.000000  2.900000e+06
# 75%         4.000000    1.000000     5.000000  137.000000  3.880000e+06
# max         6.000000   15.000000    10.000000  504.000000  3.950000e+08
#
#             floor  hasElevator   hasParking     hasBars   hasStorage   \
# count  674.000000    691.000000   691.000000  690.000000   691.000000
# mean     3.213650      0.652677     0.519537    0.349275     0.460203
# std      3.648207      0.476464     0.499980    0.477087     0.498775
# min      0.000000      0.000000     0.000000    0.000000     0.000000
# 25%      1.000000      0.000000     0.000000    0.000000     0.000000
# 50%      2.000000      1.000000     1.000000    0.000000     0.000000
# 75%      4.000000      1.000000     1.000000    1.000000     1.000000
# max     29.000000      1.000000     1.000000    1.000000     1.000000
#
#        condition   hasAirCondition   hasBalcony    hasMamad   \
# count  689.000000        691.000000   691.000000  691.000000
# mean     0.928882          0.835022     0.538350    0.581766
# std      0.257208          0.371430     0.498888    0.493626
# min      0.000000          0.000000     0.000000    0.000000
# 25%      1.000000          1.000000     0.000000    0.000000
# 50%      1.000000          1.000000     1.000000    1.000000
# 75%      1.000000          1.000000     1.000000    1.000000
# max      1.000000          1.000000     1.000000    1.000000
#
#        handicapFriendly   furniture
# count         691.000000  693.000000
# mean            0.471780    0.246753
# std             0.499565    0.431433
# min             0.000000    0.000000
# 25%             0.000000    0.000000
# 50%             0.000000    0.000000
# 75%             1.000000    0.000000
# max             1.000000    1.000000
